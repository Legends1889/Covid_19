# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/Users/mac/Desktop/dataset.csv')

# %%
df1 = df.fillna('NA')

# %%
df1.head(5)
# Out:
#    Id County Province_State Country_Region  Population    Weight       Date  \
# 0   1     NA             NA    Afghanistan    27657145  0.058359  2020/1/23
# 1   2     NA             NA    Afghanistan    27657145  0.583587  2020/1/23
# 2   3     NA             NA    Afghanistan    27657145  0.058359  2020/1/24
# 3   4     NA             NA    Afghanistan    27657145  0.583587  2020/1/24
# 4   5     NA             NA    Afghanistan    27657145  0.058359  2020/1/25
#
#            Target  TargetValue
# 0  ConfirmedCases            0
# 1      Fatalities            0
# 2  ConfirmedCases            0
# 3      Fatalities            0
# 4  ConfirmedCases            0

# %%
##extract confirmed cases and groupby date

# %%
df_cases = df1['TargetValue'].groupby(df1['Date']).sum()

# %%
##check if the time series date is stationary

# %%
df_cases.plot(figsize=(12,8))

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
## get the figure of acf

# %%
plot_acf(df_cases)
